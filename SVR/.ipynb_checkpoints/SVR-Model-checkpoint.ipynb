# %% [markdown]
# **Outline:**
#
# 1. [Libraries and settings](#1-bullet)
# 2. [Train and Evaluate Model](#2-bullet)
# 3. [Predictions](#3-bullet)

# %% [markdown]
# ## 1. [Libraries and settings](#1-bullet)

# %%
from DataPreprocessing import *
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4099 entries, 0 to 4098
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         4099 non-null   float64
#  1   High         4099 non-null   float64
#  2   Low          4099 non-null   float64
#  3   Close        4099 non-null   float64
#  4   Volume       4099 non-null   int64
#  5   TradingDate  4099 non-null   object
#  6   Code         4099 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 256.2+ KB

# %% [markdown]
# ## 2. [Train and Evaluate Model](#2-bullet)

# %% [markdown]
# ### Create dataset

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]  
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 30
x_for_train, y_for_train = create_dataset(scaled_data, time_step)

x_for_train = x_for_train.reshape(x_for_train.shape[0],x_for_train.shape[1])
y_for_train = y_for_train.reshape(y_for_train.shape[0],1)

# %%
training_size=int(len(dataset)*0.8)
test_size=len(dataset)-training_size
train_data,test_data=scaled_data[0:training_size],scaled_data[training_size:len(dataset)]
print("train_data: ", train_data.shape)
print("test_data: ", test_data.shape)
# Out:
# train_data:  (3279, 1)
# test_data:  (820, 1)

# %%
x_train, y_train = create_dataset(train_data, time_step)
x_test, y_test = create_dataset(test_data, time_step)

x_train =x_train.reshape(x_train.shape[0],x_train.shape[1])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1])
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)

print("x_train: ", x_train.shape)
print("y_train: ", y_train.shape)
print("x_test: ", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train:  (3248, 30)
# y_train:  (3248, 1)
# x_test:  (789, 30)
# y_test (789, 1)

# %% [markdown]
# ### Building model

# %% [markdown]
# Using best hyperparameters after tuning to retrain model

# %%
# Create and train the SVR model
svr_model = SVR(C = 1, kernel = 'linear', gamma = 0.01)
svr_model.fit(x_train, y_train)
# Out:
# SVR(C=1, gamma=0.01, kernel='linear')

# %%
predictions = svr_model.predict(x_test)
predictions = predictions.reshape(-1,1)

predictions_train = svr_model.predict(x_train)
predictions_train = predictions_train.reshape(-1,1)

# %%
predictions = scaler.inverse_transform(predictions)
predictions_train = scaler.inverse_transform(predictions_train)
y_test = scaler.inverse_transform(y_test)
y_train = scaler.inverse_transform(y_train)

# %%
column_names_pred = ['Close_predict']
df_predictions = pd.DataFrame(predictions, columns=column_names_pred)

column_names_test = ['Close_test']
df_test = pd.DataFrame(y_test, columns=column_names_test)

concatenated = np.concatenate([df_predictions, df_test], axis=1)
column_names_concat = ['Close_predict', 'Close_test']
df_concatenated = pd.DataFrame(concatenated, columns = column_names_concat)

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df_predictions['Close_predict'], color='red', label='Predicted Close Price')
plt.plot(df_test['Close_test'], color='blue', label='Actual Close Price')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %% [markdown]
# ### Evaluate model

# %%
mae_train = mean_absolute_error(y_train, predictions_train)
rmse_train = np.sqrt(mean_squared_error(y_train, predictions_train))
r2_train = r2_score(y_train, predictions_train)

print("Train Mean Absolute Error:", mae_train)
print("Train Mean Squared Error:", rmse_train)
print("Train R-squared:", r2_train)
# Out:
# Train Mean Absolute Error: 161.20889896474378
# Train Mean Squared Error: 335.98019913293524
# Train R-squared: 0.99537654961258

# %%
mae_test = mean_absolute_error(y_test, predictions)
rmse_test = np.sqrt(mean_squared_error(y_test, predictions))
r2_test = r2_score(y_test, predictions)

print("Test Mean Absolute Error:", mae_test)
print("Test Root Mean Squared Error:", rmse_test)
print("Test R-squared:", r2_test)
# Out:
# Test Mean Absolute Error: 363.1253356302826
# Test Root Mean Squared Error: 642.758933977918
# Test R-squared: 0.9929230419874118

# %% [markdown]
# ## 3. [Predictions](#4-bullet)

# %%
last_30_days = x_test[-1:, :]  
next_days = []  

for _ in range(101):
    input_data = np.reshape(last_30_days, (last_30_days.shape[0], last_30_days.shape[1]))

    predicted_price = svr_model.predict(input_data)
    next_day = predicted_price
    next_days.append(next_day)

    last_30_days = np.append(last_30_days[:, 1:], np.expand_dims(next_day, axis=0), axis=1)
    
pop_price = next_days.pop(0)
print("Predicted prices for the next days:")
    
for i, price in enumerate(next_days):
    price = scaler.inverse_transform(price.reshape(-1,1))
    print(f"Day {i+1}: {price}")
    
next_days = scaler.inverse_transform(np.array(next_days).reshape(-1,1))
# Out:
# Predicted prices for the next days:
# Day 1: [[8337.14924993]]
# Day 2: [[8378.88004585]]
# Day 3: [[8246.27522671]]
# Day 4: [[8106.04256063]]
# Day 5: [[8075.47636432]]
# Day 6: [[7989.56795168]]
# Day 7: [[7993.03567176]]
# Day 8: [[8059.10722019]]
# Day 9: [[8157.68841246]]
# Day 10: [[8120.44178389]]
# Day 11: [[8036.51169387]]
# Day 12: [[8130.31846644]]
# Day 13: [[8160.92902561]]
# Day 14: [[8118.04317527]]
# Day 15: [[8038.03742153]]
# Day 16: [[8043.75039313]]
# Day 17: [[8122.8148365]]
# Day 18: [[8219.98962765]]
# Day 19: [[8210.90087099]]
# Day 20: [[8188.23554565]]
# Day 21: [[8125.66215281]]
# Day 22: [[8068.73157876]]
# Day 23: [[8115.96397925]]
# Day 24: [[8158.95628092]]
# Day 25: [[8101.3938608]]
# Day 26: [[8115.50714217]]
# Day 27: [[8197.7328697]]
# Day 28: [[8237.0895622]]
# Day 29: [[8249.21224743]]
# Day 30: [[8239.05137125]]
# Day 31: [[8246.56766043]]

# %%
y_test = np.concatenate([y_test, next_days], axis=0)

# %%
plt.figure(figsize=(16, 6))
plt.title('Close Price History')
plt.plot(y_test[:-100], color='red', label='Actual Close Price')
plt.plot(range(len(y_test)-100, len(y_test)), y_test[-100:], color='blue', label='Predicted Close Price in next days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.legend()
plt.show()

# %%
last_60_days = np.array([y_test[i] for i in range(-1, -61, -1)])
next_days = []  
for i in range(60):
    input_data = x_test[i-60].reshape(-1,30)

    predicted_price = svr_model.predict(input_data)
    next_days.append(predicted_price)

#     
# pop_price = next_days.pop(0)
print("Predicted prices for the next days:")
    
for i, price in enumerate(next_days):
    price = scaler.inverse_transform(price.reshape(-1,1))
    print(f"Day {i+1}: {price}")
    
next_days = scaler.inverse_transform(np.array(next_days).reshape(-1,1))

# %%
plt.figure(figsize=(16, 6))
plt.title('Close Price History')
plt.plot(y_test[:], color='red', label='Actual Close Price')
plt.plot(range(len(y_test)-60, len(y_test)), next_days, color='blue', label='Predicted Close Price in next days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.legend()
plt.show()
